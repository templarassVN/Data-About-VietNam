# %%
import pandas as pd
import numpy as np

# %%
def Fix_northern(data):
    tinh_thieu_CO = np.array(['Cao Bằng','Phú Thọ'])
    tinh_thieu_O3 = np.array(['Thái Nguyên'])
    tinh_thieu_NO2 = np.array(['Quảng Ninh'])
    col_CO = ['CO','NO2','O3','PM-10','PM-2-5','SO2']
    col_O3 = ['O3','PM-10','PM-2-5','SO2']
    col_NO2 = ['NO2','O3','PM-10','PM-2-5','SO2']
    
    fix = data.loc[data['Tỉnh'].isin(tinh_thieu_CO),col_CO]
    done = fix[col_CO].shift(1,axis="columns")
    data.loc[data['Tỉnh'].isin(tinh_thieu_CO),col_CO] = done.values
    
    fix = data.loc[data['Tỉnh'].isin(tinh_thieu_O3),col_O3]
    done = fix[col_O3].shift(1,axis="columns")
    data.loc[data['Tỉnh'].isin(tinh_thieu_O3),col_O3] = done.values
    
    fix = data.loc[data['Tỉnh'].isin(tinh_thieu_NO2),col_NO2]
    done = fix[col_NO2].shift(1,axis="columns")
    data.loc[data['Tỉnh'].isin(tinh_thieu_NO2),col_NO2] = done.values
    
    
    return data

# %%
data_37 = pd.read_csv("./Crawl Data/aqi_MienBac.txt",sep = '\t')

# %%
data_37
# Out:
#             Tỉnh                        Vị trí  Nhiệt độ  Độ ẩm  Tốc độ gió  \
# 0        Gia Lai   ('13.998599', '107.996482')     28.77     57        2.72
# 1        Ðà Nẵng         ('16.074', '108.217')     35.00     49        0.51
# 2       Cao Bằng        ('22.6782', '106.245')     29.54     80        0.63
# 3        Phú Thọ      ('21.33847', '105.3673')     31.92     65        1.54
# 4    Thái Nguyên  ('21.593151', '105.8431043')     31.88     67        0.77
# ..           ...                           ...       ...    ...         ...
# 905      Phú Thọ      ('21.33847', '105.3673')     26.92     60        3.15
# 906       Hà Nội       ('21.0491', '105.8831')     27.01     52        3.70
# 907     Bắc Ninh  ('21.1527453', '106.111371')     27.06     56        3.65
# 908  Thái Nguyên  ('21.593151', '105.8431043')     26.88     61        2.16
# 909   Quảng Ninh   ('21.006517', '107.344252')     26.88     61        2.16
#
#      Áp suất          Ngày giờ  VN_AQI  CO  NO2  O3  PM-10  PM-2-5   SO2
# 0       1010  03/07/2021 08:00      50   4   10   5     36    50.0  14.0
# 1       1007  03/07/2021 08:00      43  10   10  13     34    43.0  40.0
# 2       1004  03/07/2021 08:00      74   0    1  57     74     1.0   NaN
# 3       1003  03/07/2021 08:00      30   9   10  17     30     NaN   NaN
# 4       1003  03/07/2021 08:00      45   6   15  43     45    15.0   NaN
# ..       ...               ...     ...  ..  ...  ..    ...     ...   ...
# 905     1007  10/07/2021 13:00      25   8   25   7     12     NaN   NaN
# 906     1007  10/07/2021 13:00      20  10   11  16     14    20.0   8.0
# 907     1007  10/07/2021 13:00      53   1    6  15     51    53.0  37.0
# 908     1007  10/07/2021 13:00      55   4    2  41     55     5.0   NaN
# 909     1007  10/07/2021 12:00      66   8   19   2      4    66.0   NaN
#
# [910 rows x 14 columns]

# %%
data_37 = Fix_northern(data_37)
tinh_thieu_CO = np.array(['Cao Bằng','Phú Thọ','Quảng Ninh'])
tinh_thieu_O3 = np.array(['Thái nguyên'])
tinh_thieu_NO2 = np.array(['Quảng Ninh'])
data_37[data_37['Tỉnh'].isin(tinh_thieu_CO)]
# Out:
#            Tỉnh                       Vị trí  Nhiệt độ  Độ ẩm  Tốc độ gió  \
# 2      Cao Bằng       ('22.6782', '106.245')     29.54     80        0.63
# 3       Phú Thọ     ('21.33847', '105.3673')     31.92     65        1.54
# 8    Quảng Ninh  ('21.006517', '107.344252')     32.06     50        1.83
# 11     Cao Bằng       ('22.6782', '106.245')     29.77     79        0.75
# 12      Phú Thọ     ('21.33847', '105.3673')     32.92     59        1.81
# ..          ...                          ...       ...    ...         ...
# 897     Phú Thọ     ('21.33847', '105.3673')     29.92     52        2.71
# 901  Quảng Ninh  ('21.006517', '107.344252')     29.88     55        2.19
# 904    Cao Bằng       ('22.6782', '106.245')     33.12     54        3.33
# 905     Phú Thọ     ('21.33847', '105.3673')     26.92     60        3.15
# 909  Quảng Ninh  ('21.006517', '107.344252')     26.88     61        2.16
#
#      Áp suất          Ngày giờ  VN_AQI   CO   NO2    O3  PM-10  PM-2-5   SO2
# 2       1004  03/07/2021 08:00      74  NaN   0.0   1.0   57.0    74.0   1.0
# 3       1003  03/07/2021 08:00      30  NaN   9.0  10.0   17.0    30.0   NaN
# 8       1003  03/07/2021 07:00      59  9.0   NaN  20.0    1.0     3.0  59.0
# 11      1004  03/07/2021 09:00      76  NaN   0.0   1.0   64.0    76.0   1.0
# 12      1003  03/07/2021 09:00      29  NaN   7.0  16.0   16.0    29.0   NaN
# ..       ...               ...     ...  ...   ...   ...    ...     ...   ...
# 897     1007  10/07/2021 12:00      22  NaN  10.0  22.0    7.0    12.0   NaN
# 901     1008  10/07/2021 11:00      65  8.0   NaN  20.0    2.0     6.0  65.0
# 904     1007  10/07/2021 13:00      69  NaN   0.0   1.0   69.0    45.0   1.0
# 905     1007  10/07/2021 13:00      25  NaN   8.0  25.0    7.0    12.0   NaN
# 909     1007  10/07/2021 12:00      66  8.0   NaN  19.0    2.0     4.0  66.0
#
# [327 rows x 14 columns]

# %%
data_nort_add = pd.read_csv("./Crawl Data/Fixed data/aqi_MienBac.txt",sep = '\t')
data_nort_add = Fix_northern(data_nort_add)

# %%
total = pd.concat([data_37,data_nort_add], ignore_index = True )

# %%
import os             
all_files = os.listdir("./Crawl Data/Addition/")
all_files
# Out:
# ['Bac Ninh.txt',
#  'Can tho.txt',
#  'Cao bang.txt',
#  'Da nang.txt',
#  'Gia lai.txt',
#  'Ha noi.txt',
#  'HCM.txt',
#  'Hung Yen.txt',
#  'Nghe An.txt',
#  'Phu tho.txt',
#  'Quang Ninh.txt',
#  'Thai nguyen.txt']

# %%
all_files = ['Bac Ninh.txt','Cao bang.txt','Da nang.txt','Gia lai.txt','Ha noi.txt','Hung Yen.txt','Phu tho.txt','Quang Ninh.txt','Thai nguyen.txt']
for file in all_files:
    path = './Crawl Data/Addition/'
    data_add = pd.read_csv(path + file,sep = '\t')
    data_add = Fix_northern(data_add)
    total = pd.concat([total,data_add],ignore_index = True )

# %%
data_trung = pd.read_csv("./Crawl Data/aqi_MienTrung.txt",sep = '\t')
data_add = pd.read_csv("./Crawl Data/Fixed data/aqi_MienTrung.txt",sep = '\t')
total_trung = pd.concat([data_trung,data_add],ignore_index = True)
all_files = ['Nghe An.txt']
for file in all_files:
    path = './Crawl Data/Addition/'
    data_add = pd.read_csv(path + file,sep = '\t')
    total_trung = pd.concat([total_trung,data_add],ignore_index = True )
total_trung.head()
# Out:
#       Tỉnh                       Vị trí  Nhiệt độ  Độ ẩm  Tốc độ gió  Áp suất  \
# 0  Nghệ An  ('18.675369', '105.690945')     31.60     61        3.18     1004
# 1  Nghệ An  ('18.675369', '105.690945')     33.68     54        4.05     1004
# 2  Nghệ An  ('18.675369', '105.690945')     35.45     47        4.25     1003
# 3  Nghệ An  ('18.675369', '105.690945')     36.47     44        4.75     1002
# 4  Nghệ An  ('18.675369', '105.690945')     36.82     47        4.80     1004
#
#            Ngày giờ  VN_AQI  PM-10  PM-2-5
# 0  03/07/2021 08:00      26     26      19
# 1  03/07/2021 09:00      23     23      15
# 2  03/07/2021 10:00      20     20      11
# 3  03/07/2021 11:00      19     19       8
# 4  03/07/2021 12:00      17     17       6

# %%
data_nam = pd.read_csv("./Crawl Data/aqi_MienNam.txt",sep = '\t')
data_add = pd.read_csv("./Crawl Data/Fixed data/aqi_MienNam.txt",sep = '\t')
total_nam = pd.concat([data_nam,data_add],ignore_index = True)
all_files = ['Can tho.txt','HCM.txt']
for file in all_files:
    path = './Crawl Data/Addition/'
    data_add = pd.read_csv(path + file,sep = '\t')
    total_nam = pd.concat([total_nam,data_add],ignore_index = True )
total_nam
# Out:
#                 Tỉnh                       Vị trí  Nhiệt độ  Độ ẩm  \
# 0    Tp. Hồ Chí Minh   ('10.65961', '106.727916')     31.01     79
# 1            Cần Thơ  ('10.026977', '105.768249')     29.99     79
# 2    Tp. Hồ Chí Minh   ('10.65961', '106.727916')     32.01     70
# 3            Cần Thơ  ('10.026977', '105.768249')     30.99     79
# 4    Tp. Hồ Chí Minh   ('10.65961', '106.727916')     34.01     62
# ..               ...                          ...       ...    ...
# 343  Tp. Hồ Chí Minh   ('10.65961', '106.727916')     25.01     92
# 344  Tp. Hồ Chí Minh   ('10.65961', '106.727916')     25.01     91
# 345  Tp. Hồ Chí Minh   ('10.65961', '106.727916')     24.01     97
# 346  Tp. Hồ Chí Minh   ('10.65961', '106.727916')     24.01     96
# 347  Tp. Hồ Chí Minh   ('10.65961', '106.727916')     25.01     95
#
#      Tốc độ gió  Áp suất          Ngày giờ  VN_AQI  PM-10  PM-2-5
# 0          1.54     1009  03/07/2021 08:00      23     23      21
# 1          1.54     1009  03/07/2021 08:00      21     21      19
# 2          1.54     1009  03/07/2021 09:00      24     24      23
# 3          2.06     1009  03/07/2021 09:00      19     19      16
# 4          2.57     1008  03/07/2021 10:00      26     26      25
# ..          ...      ...               ...     ...    ...     ...
# 343        2.32     1006  08/07/2021 05:00      18     18      12
# 344        1.78     1007  08/07/2021 04:00      15     15      10
# 345        1.32     1008  08/07/2021 03:00      16     16       9
# 346        2.19     1008  08/07/2021 02:00      17     17       9
# 347        2.56     1009  08/07/2021 01:00      19     19       9
#
# [348 rows x 10 columns]

# %%
final = pd.concat([total,total_nam,total_trung],ignore_index = True)

# %%
total['Tỉnh'].unique()
# Out:
# array(['Gia Lai', 'Ðà Nẵng', 'Cao Bằng', 'Phú Thọ', 'Thái Nguyên',
#        'Hà Nội', 'Bắc Ninh', 'Hưng Yên', 'Quảng Ninh'], dtype=object)

# %%
def Mien(row):
    bac = np.array(['Cao Bằng', 'Phú Thọ', 'Thái Nguyên',
       'Hà Nội', 'Bắc Ninh', 'Hưng Yên', 'Quảng Ninh'])
    trung = np.array(['Gia Lai', 'Ðà Nẵng','Nghệ An'])
    nam = np.array(['Tp. Hồ Chí Minh','Cần Thơ'])
    if  row['Tỉnh'] in bac:
        return 1
    if row['Tỉnh'] in trung:
        return 2
    if row['Tỉnh'] in nam:
        return 3
final['Miền'] = final.apply (lambda row: Mien(row), axis=1)

# %%
final.sort_values(by=['Tỉnh','Ngày giờ'])
# Out:
#          Tỉnh                        Vị trí  Nhiệt độ  Độ ẩm  Tốc độ gió  \
# 6    Bắc Ninh  ('21.1527453', '106.111371')     32.06     50        1.83
# 15   Bắc Ninh  ('21.1527453', '106.111371')     33.06     44        3.05
# 24   Bắc Ninh  ('21.1527453', '106.111371')     34.06     41        3.94
# 33   Bắc Ninh  ('21.1527453', '106.111371')     34.06     40        4.61
# 42   Bắc Ninh  ('21.1527453', '106.111371')     34.06     40        4.61
# ..        ...                           ...       ...    ...         ...
# 871   Ðà Nẵng         ('16.074', '108.217')     30.00     66        2.57
# 879   Ðà Nẵng         ('16.074', '108.217')     33.00     58        4.63
# 887   Ðà Nẵng         ('16.074', '108.217')     32.00     62        4.12
# 895   Ðà Nẵng         ('16.074', '108.217')     33.00     55        5.66
# 903   Ðà Nẵng         ('16.074', '108.217')     33.00     58        5.66
#
#      Áp suất          Ngày giờ  VN_AQI   CO   NO2    O3  PM-10  PM-2-5   SO2  \
# 6       1003  03/07/2021 08:00     107  3.0  17.0  10.0   70.0   107.0  34.0
# 15      1002  03/07/2021 09:00      91  3.0  16.0  13.0   73.0    91.0  38.0
# 24      1002  03/07/2021 10:00      74  2.0   8.0  13.0   74.0    69.0  39.0
# 33      1001  03/07/2021 11:00      76  1.0   7.0  13.0   76.0    62.0  36.0
# 42      1001  03/07/2021 12:00      81  1.0   5.0  17.0   81.0    67.0  34.0
# ..       ...               ...     ...  ...   ...   ...    ...     ...   ...
# 871     1010  10/07/2021 09:00      28  2.0  11.0  14.0   16.0    24.0  28.0
# 879     1009  10/07/2021 10:00      29  2.0  11.0  15.0   15.0    22.0  29.0
# 887     1009  10/07/2021 11:00      29  2.0  10.0  20.0   13.0    18.0  29.0
# 895     1008  10/07/2021 12:00      28  2.0  11.0  20.0   10.0    16.0  28.0
# 903     1007  10/07/2021 13:00      28  1.0  10.0  20.0   10.0    13.0  28.0
#
#      Miền
# 6       1
# 15      1
# 24      1
# 33      1
# 42      1
# ..    ...
# 871     2
# 879     2
# 887     2
# 895     2
# 903     2
#
# [1994 rows x 15 columns]

# %%
final.drop(final.loc[final['Tỉnh']== 'Hưng Yên'].index, inplace=True)

# %%
final.to_csv('aqi_VietNam.csv', sep='\t', encoding='utf-8',index = False)

# %%
for tinh in final['Tỉnh'].unique().tolist():
    print(tinh+ ':' + str(final[final['Tỉnh'] == tinh].shape))
# Out:
# Gia Lai:(174, 15)
# Ðà Nẵng:(174, 15)
# Cao Bằng:(174, 15)
# Phú Thọ:(174, 15)
# Thái Nguyên:(174, 15)
# Hà Nội:(174, 15)
# Bắc Ninh:(174, 15)
# Quảng Ninh:(174, 15)
# Tp. Hồ Chí Minh:(174, 15)
# Cần Thơ:(174, 15)
# Nghệ An:(174, 15)
